# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn

# %%
env = gym.make("Ant-v4", render_mode="rgb_array")
print(type(env))
# Out:
# <class 'gymnasium.wrappers.common.TimeLimit'>
# /Users/mutyuu/miniconda3/envs/cs224r/lib/python3.11/site-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment Ant-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(

# %%
obs, info = env.reset()
print(f"Starting observation: {obs}", f"info: {info}")
# Out:
# obs shape: (27,)
# obs example: [ 0.77612643  0.99800745  0.06002256  0.01907489 -0.003818  ]
