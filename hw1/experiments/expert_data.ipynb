# %%
import pickle
import os
import pathlib

DATA_DIR = "../cs224r/expert_data"
ANT_DATA_FILE = os.path.join(DATA_DIR, "expert_data_Ant-v4.pkl")

# %%
ant_expert_data = pickle.load(open(ANT_DATA_FILE, "rb"))
print(f"first trajectory len: {len(ant_expert_data[0]['observation'])}")
print(f"first trajectory keys: {ant_expert_data[0].keys()}")
# Out:
# first trajectory len: 1000
